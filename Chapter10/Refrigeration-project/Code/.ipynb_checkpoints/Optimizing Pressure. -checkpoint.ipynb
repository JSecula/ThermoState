# %%
from thermostate import State, Q_, units
import numpy as np
from math import pi
substance1 = 'R22'
substance2 = 'R134a'
substance3 = 'ammonia'
substanceR = 'air'

Pwr_i = Q_(281.3, 'kWh')   #Converted from Tons of Refrigerant
Cost_i = (15.225) #In cents/kWh
Cost_f = (18.268) #In Cents/kWh
Q_in = Q_(80,'ton_of_refrigeration')
#_____________________________________________________________________ Line
print('Jason Secula'.center(85))
print('Applied Thermodynamics [ME 2234] '.center(85))
print('Professor Bryan W. Weber '.center(85))
print('Vapor-Compression Refrigeration System'.center(85))
print('           ')
#_____________________________________________________________________ Line
#__________________________Air to be cooled___________________________
#_____________________________________________________________________import numpy as np
T_4 = Q_(-32, 'degC')
p_4 = Q_(1.5049, 'bar')
st_4 = State(substance1, T=T_4,p=p_4) #Need a pressure that will have a super heated vapor
print ('Phase of State 4             {}'.format(st_4.phase))
print ('Enthalpy at State 4           {}'.format(st_4.h))
print('           ')

T_4a = Q_(-40, 'degC')
p_4a = Q_(1.0522, 'bar')
st_4a = State(substance1, T=T_4a,p=p_4a) #Need a pressure that will have a super heated vapor
print ('Phase of State 4a             {}'.format(st_4a.phase))
print ('Enthalpy at State 4a           {}'.format(st_4a.h))
print('           ')

T_4b = Q_(-45, 'degC')
p_4b = Q_(0.8290, 'bar')
st_4b = State(substance1, T=T_4b,p=p_4b) #Need a pressure that will have a super heated vapor
print ('Phase of State 4b             {}'.format(st_4b.phase))
print ('Enthalpy at State 4b           {}'.format(st_4b.h))
print('           ')

T_4c = Q_(-50, 'degC')
p_4c = Q_(0.6451, 'bar')
st_4c = State(substance1, T=T_4c,p=p_4c) #Need a pressure that will have a super heated vapor
print ('Phase of State 4c             {}'.format(st_4c.phase))
print ('Enthalpy at State 4c           {}'.format(st_4c.h))
print('           ')


    
    
    
    
    
    
    
    
Qin_mdot = (st_1.h-st_4.h)
mdot = Q_in/(st_1.h-st_4.h)
Qin = (Q_in/mdot)
print ('Phase of State 1             {}'.format(st_1.phase))
print ('Pressure at State 1           {}'.format(p_1.to('bar')))
print ('Enthalpy at State 1           {}'.format(st_1.h))
print ('Qin/mdot                      {}'.format(Qin_mdot))
print ('Qin                           {}'.format(Qin))
print('           ')
# Out:
#                                      Jason Secula
#                           Applied Thermodynamics [ME 2234]
#                               Professor Bryan W. Weber
#                         Vapor-Compression Refrigeration System
#
# Phase of State 4             liquid
# Enthalpy at State 4           174796.5656937871 joule / kilogram
#
# Phase of State 4a             liquid
# Enthalpy at State 4a           168100.30490391538 joule / kilogram
#
# Phase of State 4b             liquid
# Enthalpy at State 4b           165882.37252042638 joule / kilogram
#
# Phase of State 4c             gas
# Enthalpy at State 4c           391793.59715947934 joule / kilogram
#
# Phase of State 1             supercritical
# Pressure at State 1           5306.906471827524 bar
# Enthalpy at State 1           447363.3833061106 joule / kilogram
# Qin/mdot                      272566.81761232356 joule / kilogram
# Qin                           272566.81761232356 joule / kilogram
