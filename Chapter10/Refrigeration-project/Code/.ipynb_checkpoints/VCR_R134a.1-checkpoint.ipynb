# %%
from thermostate import State, Q_, units
from math import pi
import numpy as np
substance1 = 'R22'
#^^ From my notes, P_saturated, at 4 Degrees C, 5.6619 Bar
substance2 = 'R134a'
substance3 = 'ammonia'

#_____________________________________________________________________ Line
Pwr_i = Q_(281.3, 'kW').to('J/s')   #Converted from Tons of Refrigerant
Cost_i = (15.225) #In cents/kWh
Cost_f = (18.268) #In Cents/kWh
Q_in = Q_(80,'ton_of_refrigeration').to('J/s')
Pwr = Q_(250, 'kWh')
R_bar = Q_(8.31446,'J/(mol*K)')                 #Mdot Calculations in Book on Page 635
#_____________________________________________________________________
#Temp of Room is 2DegreesC
#Temperture of the is 40 degrees to be cooled to 2 degrees C
T_EvapHigh = Q_(-18,'dimensionless')   #(-50+18)/2 = 16 Loops
T_EvapLow = Q_(-50,'dimensionless')
TUnit = Q_(1, 'degC')
T_CndrHigh = Q_(92,'dimensionless')   #(92-60)/2 =  16 Loops
T_CndrLow = Q_(60,'dimensionless')
β = []
W_c = []
Q_out=[]

St1 = 0
T_range = np.arange(T_EvapLow, T_EvapHigh, 2)
for TEvap in T_range:
    St1 += 1
    St2 = 0
    T_4 = TUnit*TEvap
    x_4 = Q_(0.0, 'dimensionless')                    #Table A7, page 937
    st_4 = State(substance2, T=T_4,x=x_4)      #Need a pressure that will have a super heated vapor
    x_1 = Q_(1.0,'dimensionless')
    st_1 = State(substance2, T=T_4, x=x_1) #Need a pressure that will have a super heated vapor
    mdot = (Q_in/(st_1.h-st_4.h))
    T_rng = np.arange(T_CndrLow, T_CndrHigh, 2)
    for TCndr in T_rng:
        St2 += 1
        EC = 0
        T_2s = TUnit*TCndr
        st_2s = State(substance2,T=T_2s, s=st_1.s)                      #
        T_3 = Q_(40,'degC')
        p_3 = Q_(24.281, 'bar')
        st_3 = State(substance2, p=p_3 , T=T_3)
        st_2 = State(substance2,p=st_3.p,s=st_1.s)                      #
        Q_out = mdot*(st_2s.h- st_3.h)
        W_comp = (mdot*(st_2s.h-st_1.h)).to('kJ/s')
        βeta = (Q_in/W_comp)
        eta_c = ((st_2s.h-st_1.h)/(st_2.h-st_1.h))
        if (eta_c > 0.8 and eta_c < 1):
            EC += 1
            print('State1 Test           {}, times'.format(St1))
            print(('State2s Test           {}, times'.format(St2)))
            print('Eta  Test           {}, times'.format(EC))
            print('________________________________________________________________________') 
            print ('____State 4___________________________')
            print ('           T = {}'.format(st_4.T.to('degC')))
            print ('           P = {}'.format(st_4.p.to('bar')))
            print ('           h = {}'.format(st_4.h))
            print ('           s = {}'.format(st_4.s))
            print ('____State 1___________________________')
            print ('           T = {}'.format(st_1.T.to('degC')))
            print ('           P = {}'.format(st_1.p.to('bar')))
            print ('           h = {}'.format(st_1.h))
            print ('           s = {}'.format(st_1.s))
            print ('____State 2s__________________________')
            print ('           T = {}'.format(st_2s.T.to('degC')))
            print ('           P = {}'.format(st_2s.p.to('bar')))
            print ('           h = {}'.format(st_2s.h))
            print ('           s = {}'.format(st_2s.s))
            print ('____State 2___________________________')
            print ('           T = {}'.format(st_2.T.to('degC')))
            print ('           P = {}'.format(st_2.p.to('bar')))
            print ('           h = {}'.format(st_2.h))
            print ('           s = {}'.format(st_2.s))
            print ('____State 3___________________________')
            print ('           T = {}'.format(st_3.T.to('degC')))
            print ('           P = {}'.format(st_3.p.to('bar')))
            print ('           h = {}'.format(st_3.h))
            print ('           s = {}'.format(st_3.s))
            print('________________________________________________________________________') 
            print(' mdot  is {} '.format(mdot).center(85))
            print(' Q_in  is {} '.format(Q_in.to('ton_of_refrigeration')).center(85))
            print(' Q_out is {} '.format(Q_out.to('ton_of_refrigeration')).center(85))
            print(' W_c   is {} '.format(W_comp.to('kW')).center(85))
            print(' η_c   is {} '.format(eta_c).center(85))
            print(' β     is {} '.format(βeta.to('kJ/kJ')).center(85))
            print('________________________________________________________________________')  
            print('           ')
# Out:
# State1 Test           1, times
# State2s Test           3, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 64.0 degC
#            P = 11.075582499011043 bar
#            h = 443875.4769117843 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 64.72384171640012 refrigeration_ton
#                          W_c   is 92.44535375000227 kilowatt
#                       η_c   is 0.8099442699168276 dimensionless
#                       β     is 3.0434004084853896 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           4, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 66.0 degC
#            P = 11.644841482819114 bar
#            h = 445031.14532231644 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                       Q_out is 65.122385136727 refrigeration_ton
#                          W_c   is 93.84697231046583 kilowatt
#                       η_c   is 0.8222243129433978 dimensionless
#                        β     is 2.997946768432478 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           5, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 68.0 degC
#            P = 12.236561190227574 bar
#            h = 446173.4241440318 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 65.51631102794677 refrigeration_ton
#                          W_c   is 95.23235170056569 kilowatt
#                       η_c   is 0.8343620792361924 dimensionless
#                       β     is 2.9543345548155986 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           6, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 70.0 degC
#            P = 12.85118801269876 bar
#            h = 447302.0547055104 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 65.90553018472032 refrigeration_ton
#                          W_c   is 96.60117819825153 kilowatt
#                       η_c   is 0.8463548201727367 dimensionless
#                       β     is 2.9124720072040033 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           7, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 72.0 degC
#            P = 13.489155380094779 bar
#            h = 448416.7983544888 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 66.28996030550813 refrigeration_ton
#                          W_c   is 97.95316236112019 kilowatt
#                       η_c   is 0.8581999998525618 dimensionless
#                       β     is 2.8722730393133964 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           8, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 74.0 degC
#            P = 14.150883661658444 bar
#            h = 449517.4376565136 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 66.66952640593756 refrigeration_ton
#                           W_c   is 99.2880404801676 kilowatt
#                       η_c   is 0.8698953078340056 dimensionless
#                        β     is 2.833656762734999 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           9, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 76.0 degC
#            P = 14.836780326690908 bar
#            h = 450603.7775672014 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                       Q_out is 67.044161223068 refrigeration_ton
#                          W_c   is 100.6055760015299 kilowatt
#                       η_c   is 0.8814386715905562 dimensionless
#                       β     is 2.7965470558118453 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           10, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 78.0 degC
#            P = 15.547240393733087 bar
#            h = 451675.6465728575 joule / kilogram
#            s = 1780.574845461244 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 67.41380560874421 refrigeration_ton
#                          W_c   is 101.9055609098493 kilowatt
#                       η_c   is 0.8928282686309766 dimensionless
#                       β     is 2.7608721727583427 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           11, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 80.0 degC
#            P = 16.28264719732257 bar
#            h = 452732.8977942667 joule / kilogram
#            s = 1780.574845461244 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 67.77840891024934 refrigeration_ton
#                          W_c   is 103.18781706697449 kilowatt
#                       η_c   is 0.9040625382281017 dimensionless
#                       β     is 2.7265643887274305 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           12, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 82.0 degC
#            P = 17.043373501442254 bar
#            h = 453775.41004853643 joule / kilogram
#            s = 1780.574845461243 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 68.13792933649171 refrigeration_ton
#                          W_c   is 104.45219749978598 kilowatt
#                       η_c   is 0.9151401927019005 dimensionless
#                       β     is 2.6935596770561934 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           13, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 84.0 degC
#            P = 17.829782988573264 bar
#            h = 454803.0888639682 joule / kilogram
#            s = 1780.5748454612371 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 68.49233430799308 refrigeration_ton
#                          W_c   is 105.6985876310531 kilowatt
#                       η_c   is 0.9260602282034215 dimensionless
#                       β     is 2.6617974153769692 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           14, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 86.0 degC
#            P = 18.642232152801817 bar
#            h = 455815.8674430266 joule / kilogram
#            s = 1780.5748454612092 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 68.84160078897777 refrigeration_ton
#                          W_c   is 106.92690644734279 kilowatt
#                       η_c   is 0.9368219349472265 dimensionless
#                        β     is 2.631220117678107 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           15, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 88.0 degC
#            P = 19.481072624692263 bar
#            h = 456813.70756857935 joule / kilogram
#            s = 1780.574845461065 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 69.18571559989839 refrigeration_ton
#                          W_c   is 108.13710759812618 kilowatt
#                       η_c   is 0.9474249068410276 dimensionless
#                        β     is 2.601773189744614 dimensionless
# ________________________________________________________________________
#
# State1 Test           1, times
# State2s Test           16, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 135673.62660823492 joule / kilogram
#            s = 741.0121309939016 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.29450522698345133 bar
#            h = 367652.04634162266 joule / kilogram
#            s = 1780.5748454612442 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 90.0 degC
#            P = 20.34665395463023 bar
#            h = 457796.6004486665 joule / kilogram
#            s = 1780.5748454603247 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 98.39769913413642 degC
#            P = 24.280999882520394 bar
#            h = 461761.522019485 joule / kilogram
#            s = 1780.5748454612444 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                      mdot  is 1.212820691203458 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 69.52467570876257 refrigeration_ton
#                          W_c   is 109.32918042033243 kilowatt
#                       η_c   is 0.9578690504621395 dimensionless
#                       β     is 2.5734047057121234 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           2, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 62.0 degC
#            P = 10.830475463371306 bar
#            h = 442166.96931417845 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 64.47088083076277 refrigeration_ton
#                          W_c   is 89.29762881681351 kilowatt
#                       η_c   is 0.8003002348797246 dimensionless
#                        β     is 3.15067971113203 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           3, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 64.0 degC
#            P = 11.388728157901825 bar
#            h = 443318.95025115064 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 64.87023534058903 refrigeration_ton
#                          W_c   is 90.70209985968818 kilowatt
#                       η_c   is 0.8128873384835632 dimensionless
#                       β     is 3.1018932064479823 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           4, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 66.0 degC
#            P = 11.969078726737115 bar
#            h = 444457.5914182685 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 65.26496538391557 refrigeration_ton
#                          W_c   is 92.09030733441016 kilowatt
#                       η_c   is 0.8253286852785703 dimensionless
#                       β     is 3.0551339821645445 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           5, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 68.0 degC
#            P = 12.571967647943177 bar
#            h = 445582.6299117755 joule / kilogram
#            s = 1777.0230235739684 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 65.6549798205182 refrigeration_ton
#                          W_c   is 93.46193071422314 kilowatt
#                       η_c   is 0.8376214026505256 dimensionless
#                        β     is 3.010297617600118 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           6, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 70.0 degC
#            P = 13.197822290570285 bar
#            h = 446693.82252403506 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 66.04019433818011 refrigeration_ton
#                          W_c   is 94.81667348546783 kilowatt
#                       η_c   is 0.8497628331945871 dimensionless
#                        β     is 2.967286417282445 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           7, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 72.0 degC
#            P = 13.847056749376039 bar
#            h = 447790.9469405707 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 66.42053186766704 refrigeration_ton
#                          W_c   is 96.15426460698852 kilowatt
#                       η_c   is 0.8617505477947366 dimensionless
#                        β     is 2.926008830864531 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           8, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 74.0 degC
#            P = 14.520071930534 bar
#            h = 448873.80291199445 joule / kilogram
#            s = 1777.0230235739684 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 66.7959229889967 refrigeration_ton
#                          W_c   is 97.47445993892329 kilowatt
#                       η_c   is 0.8735823584288347 dimensionless
#                       β     is 2.8863789298409426 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           9, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 76.0 degC
#            P = 15.217255916847293 bar
#            h = 449942.21339563443 joule / kilogram
#            s = 1777.0230235739684 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 67.1663063272043 refrigeration_ton
#                          W_c   is 98.77704363455287 kilowatt
#                       η_c   is 0.8852563306426027 dimensionless
#                        β     is 2.848315934684603 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           10, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 78.0 degC
#            P = 15.938984641317074 bar
#            h = 450996.02566172223 joule / kilogram
#            s = 1777.0230235739684 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 67.53162893582189 refrigeration_ton
#                          W_c   is 100.0618294889408 kilowatt
#                       η_c   is 0.8967707956363609 dimensionless
#                       β     is 2.8117437868396045 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           11, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 80.0 degC
#            P = 16.685622898022803 bar
#            h = 452035.112359071 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 67.89184666631435 refrigeration_ton
#                          W_c   is 101.32866223818603 kilowatt
#                       η_c   is 0.9081243619091462 dimensionless
#                       β     is 2.7765907607068585 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           12, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 138154.32138116137 joule / kilogram
#            s = 752.0681733464035 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -48.0 degC
#            P = 0.3305140142588453 bar
#            h = 368922.90590989747 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 82.0 degC
#            P = 17.457525719145178 bar
#            h = 453059.3725352574 joule / kilogram
#            s = 1777.0230235739682 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 97.3927963797712 degC
#            P = 24.280999882520398 bar
#            h = 460443.6380202519 joule / kilogram
#            s = 1777.023023573968 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.2191790660756026 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 68.24692452174362 refrigeration_ton
#                          W_c   is 102.57741880320746 kilowatt
#                       η_c   is 0.9193159264057175 dimensionless
#                        β     is 2.742789111364692 dimensionless
# ________________________________________________________________________
#
# State1 Test           2, times
# State2s Test           13, times
# Eta  Test           1, times
# ________________________________________________________________________
# ...
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 68.96697643929201 refrigeration_ton
#                          W_c   is 70.28979649437998 kilowatt
#                       η_c   is 0.8744028552251046 dimensionless
#                        β     is 4.002689457037031 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           7, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 72.0 degC
#            P = 17.539763405718 bar
#            h = 440663.96354059665 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 69.31108482984995 refrigeration_ton
#                          W_c   is 71.49997506569262 kilowatt
#                       η_c   is 0.8894574385481994 dimensionless
#                       β     is 3.9349416151101675 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           8, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 74.0 degC
#            P = 18.30993210296257 bar
#            h = 441564.7449776593 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                       Q_out is 69.649535969288 refrigeration_ton
#                          W_c   is 72.69025791732601 kilowatt
#                       η_c   is 0.9042645197449265 dimensionless
#                       β     is 3.8705080354140935 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           9, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 76.0 degC
#            P = 19.1031618189132 bar
#            h = 442450.4963643785 joule / kilogram
#            s = 1741.322434538054 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 69.98233985906562 refrigeration_ton
#                          W_c   is 73.86068022294128 kilowatt
#                       η_c   is 0.9188245363745233 dimensionless
#                       β     is 3.8091746043512047 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           10, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 78.0 degC
#            P = 19.91967586674417 bar
#            h = 443321.2742266743 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 70.30951773770005 refrigeration_ton
#                          W_c   is 75.01131667527814 kilowatt
#                       η_c   is 0.9331384176123196 dimensionless
#                       β     is 3.7507437522165055 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           11, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 80.0 degC
#            P = 20.75970306349619 bar
#            h = 444177.1655813544 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 70.63110230006765 refrigeration_ton
#                          W_c   is 76.14228225740541 kilowatt
#                       η_c   is 0.9472075938440715 dimensionless
#                       β     is 3.6950327600401023 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           12, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 82.0 degC
#            P = 21.62348229337545 bar
#            h = 445018.28844639513 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 70.94713788913211 refrigeration_ton
#                          W_c   is 77.25373291700096 kilowatt
#                       η_c   is 0.9610340050539814 dimensionless
#                       β     is 3.6418722661286176 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           13, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 84.0 degC
#            P = 22.511267604135128 bar
#            h = 445844.792286852 joule / kilogram
#            s = 1741.3224345904719 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 71.25768066348671 refrigeration_ton
#                          W_c   is 78.34586615557316 kilowatt
#                       η_c   is 0.9746201081545948 dimensionless
#                       β     is 3.5911049449201786 dimensionless
# ________________________________________________________________________
#
# State1 Test           16, times
# State2s Test           14, times
# Eta  Test           1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 173635.74380724836 joule / kilogram
#            s = 900.2459272389528 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -20.0 degC
#            P = 1.3273497949922277 bar
#            h = 386554.2616313093 joule / kilogram
#            s = 1741.3224345380538 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 86.0 degC
#            P = 23.42333389074386 bar
#            h = 446656.8583058053 joule / kilogram
#            s = 1741.3224345604397 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 87.83337089308003 degC
#            P = 24.280999882520394 bar
#            h = 447388.76541330805 joule / kilogram
#            s = 1741.3224345380534 joule / kelvin / kilogram
# ____State 3___________________________
#            T = 40.0 degC
#            P = 24.280999882520398 bar
#            h = 256193.795406229 joule / kilogram
#            s = 1185.877591553557 joule / kelvin / kilogram
# ________________________________________________________________________
#                     mdot  is 1.3213891879419206 kilogram / second
#                      Q_in  is 79.99999999999997 refrigeration_ton
#                      Q_out is 71.5627987066714 refrigeration_ton
#                          W_c   is 79.41892141291308 kilowatt
#                       η_c   is 0.9879688817693731 dimensionless
#                       β     is 3.5425843408594515 dimensionless
# ________________________________________________________________________
