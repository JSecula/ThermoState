# %%
from thermostate import State, Q_, units
import matplotlib.pyplot as plt
from math import pi
import numpy as np
substance1 = 'R22'
#^^ From my notes, P_saturated, at 4 Degrees C, 5.6619 Bar
substance2 = 'R134a'
substance3 = 'ammonia'

#_____________________________________________________________________ Line
Pwr_i = Q_(281.3, 'kW').to('J/s')   #Converted from Tons of Refrigerant
Cost_i = (15.225) #In cents/kWh
Cost_f = (18.268) #In Cents/kWh
Q_in = Q_(80,'ton_of_refrigeration').to('J/s')
Pwr = Q_(250, 'kWh')
R_bar = Q_(8.31446,'J/(mol*K)')                 #Mdot Calculations in Book on Page 635
#_____________________________________________________________________
#Temp of Room is 2DegreesC
#Temperture of the is 40 degrees to be cooled to 2 degrees C
T_EvapHigh = Q_(-18,'dimensionless')   #(-50+18)/2 = 16 Loops
T_EvapLow = Q_(-50,'dimensionless')
TUnit = Q_(1, 'degC')
T_CndrHigh = Q_(92,'dimensionless')   #(92-60)/2 =  16 Loops
T_CndrLow = Q_(60,'dimensionless')

β = []
W_c = []
Q_out=[]
η_c = []

T1 = []
T2 = []
T2s = []
T3 = []
T4 = []

S1 = []
S2 = []
S2s = []
S3 = []
S4 = []

St1 = 0
St2 = 0
EC = 0

T_range = np.arange(T_EvapLow, T_EvapHigh, 2)
for TEvap in T_range:
    St1 += 1
    T_4 = TUnit*TEvap
    x_4 = Q_(0.0, 'dimensionless')                    #Table A7, page 937
    st_4 = State(substance1, T=T_4,x=x_4)      #Need a pressure that will have a super heated vapor
    x_1 = Q_(1.0,'dimensionless')
    st_1 = State(substance1, T=T_4, x=x_1) #Need a pressure that will have a super heated vapor
    mdot = (Q_in/(st_1.h-st_4.h))
    
    T_rng = np.arange(T_CndrLow, T_CndrHigh, 2)
    for TCndr in T_rng:
        St2 += 1
        T_2s = TUnit*TCndr
        st_2s = State(substance1,T=T_2s, s=st_1.s)                      #
        T_3 = Q_(40,'degC')                                             #In the Example problem, the book set T3 to TH
        p_3 = Q_(24.281, 'bar')                                         #Values From Tables in TextBook
        st_3 = State(substance1, p=p_3 , T=T_3)
        st_2 = State(substance1,p=st_3.p,s=st_1.s)                      #
        
        Q_out = mdot*(st_2s.h- st_3.h)
        W_comp = (mdot*(st_2s.h-st_1.h)).to('kJ/s')
        βeta = (Q_in/W_comp)
        eta_c = ((st_2s.h-st_1.h)/(st_2.h-st_1.h))
        if (βeta > 1) and (eta_c > 0.8):
            EC += 1
            print ('State1 Test              {}, times'.format(St1))
            print (('State2s Test            {}, times'.format(St2)))
            print ('Eta  Test                {}, times'.format(EC))
            print ('________________________________________________________________________') 
            print ('____State 4___________________________')
            print ('           T = {}'.format(st_4.T.to('degC')))
            print ('           P = {}'.format(st_4.p.to('bar')))
            print ('           h = {}'.format(st_4.h))
            print ('           s = {}'.format(st_4.s))
            print ('____State 1___________________________')
            print ('           T = {}'.format(st_1.T.to('degC')))
            print ('           P = {}'.format(st_1.p.to('bar')))
            print ('           h = {}'.format(st_1.h))
            print ('           s = {}'.format(st_1.s))
            print ('____State 2s__________________________')
            print ('           T = {}'.format(st_2s.T.to('degC')))
            print ('           P = {}'.format(st_2s.p.to('bar')))
            print ('           h = {}'.format(st_2s.h))
            print ('           s = {}'.format(st_2s.s))
            print ('____State 2___________________________')
            print ('           T = {}'.format(st_2.T.to('degC')))
            print ('           P = {}'.format(st_2.p.to('bar')))
            print ('           h = {}'.format(st_2.h))
            print ('           s = {}'.format(st_2.s))
            print ('____State 3___________________________')
            print ('           T = {}'.format(st_3.T.to('degC')))
            print ('           P = {}'.format(st_3.p.to('bar')))
            print ('           h = {}'.format(st_3.h))
            print ('           s = {}'.format(st_3.s))
            print ('________________________________________________________________________') 
            print (' mdot  is {} '.format(mdot).center(85))
            print (' Q_in  is {} '.format(Q_in.to('ton_of_refrigeration')).center(85))
            print (' Q_out is {} '.format(Q_out.to('ton_of_refrigeration')).center(85))
            print (' W_c   is {} '.format(W_comp.to('kW')).center(85))
            print (' η_c   is {} '.format(eta_c).center(85))
            print (' β     is {} '.format(βeta.to('kJ/kJ')).center(85))
            print ('________________________________________________________________________')  
            print ('           ')


    η_c.append(eta_c.magnitude)
    η_c.sort()
    β.append(βeta.magnitude)
    β.sort()
    W_c.append(W_comp.magnitude)
    W_c.sort()
            
        
        #^^^ There is an issue with order: Loop 1 Once, Then Loop 2 sixteen times. 
        #η_cSort.sort(η_c) #https://docs.python.org/2/tutorial/datastructures.html
        #β_Sort.sort(β)               #These are not defined yet. 
        #W_cSort.sort(W_c)            #These are not defined yet. 
        #^^^Now I can plot those....If I had more time.....
    #Outside of the Inner 2 loops to reduce Data
    T4.append(st_4.T.magnitude)
    T1.append(st_1.T.magnitude)
    T2s.append(st_2s.T.magnitude)
    T2.append(st_2.T.magnitude)
    T3.append(T_3.magnitude)
        
    S4.append(st_4.s.magnitude)
    S1.append(st_1.s.magnitude)
    S2s.append(st_2s.s.magnitude)
    S2.append(st_2.s.magnitude)
    S3.append(st_3.s.magnitude)

    
    T =[T4, T1, T2s, T2, T3] #I think If I split this into two seperate loops, it might work better. 
    s =[S4, S1, S2s, S2, S3]
    #So I should probably sort T4, T1 ..., and S4, S1... 
    #Once sorted, I can use the  .pop() or another loop, to find the ideal specific data point.
                                #^https://docs.python.org/2/tutorial/datastructures.html
    # %matplotlib inline
    import matplotlib.pyplot as plt
    fig, Ts_ax = plt.subplots(231)
    Ts_ax.plot(S4, T4, label='Ts Diagram', color='C0')
    Ts_ax.set_xlabel('Entropy')
    Ts_ax.set_ylabel('Temperature')
    lines, labels = Ts_ax.get_legend_handles_labels()
    Ts_ax.legend(lines, labels, loc='best');
    
    fig, Ts2_ax = plt.subplots(232)
    Ts2_ax.plot(S1, T1, label='Ts Diagram', color='C1')
    fig, Ts3_ax = plt.subplots(234)
    Ts3_ax.plot(S2s, T2s, label='Ts Diagram', color='C2')
    fig, Ts4_ax = plt.subplots(235)
    Ts4_ax.plot(S2, T2, label='Ts Diagram', color='C3')
print ('Coefficent of Performance {}'.format(β))
print ('The power needed to run the compressor was {}'.format(W_c))
print ('Creating an overall thermal effciency of {}'.format (η_c))

#%matplotlib inline
#fig, Weta_ax = plt.subplots()
#Weta_ax.plot(η_c, W_c, label='The thermal Efficiency compaired to work input.', color='C0')
#Weta_ax.set_xlabel('Thermal Efficency')
#Weta_ax.set_ylabel('Work in')
# Out:
# State1 Test              1, times
# State2s Test            16, times
# Eta  Test                1, times
# ________________________________________________________________________
# ____State 4___________________________
#            T = -50.0 degC
#            P = 0.6453040827878886 bar
#            h = 144025.2294589678 joule / kilogram
#            s = 775.2469648508827 joule / kelvin / kilogram
# ____State 1___________________________
#            T = -50.0 degC
#            P = 0.6453040827878886 bar
#            h = 383416.4336469921 joule / kilogram
#            s = 1848.0285207013358 joule / kelvin / kilogram
# ____State 2s__________________________
#            T = 90.0 degC
#            P = 13.306508555526644 bar
#            h = 462712.0847416722 joule / kilogram
#            s = 1848.0285207202044 joule / kelvin / kilogram
# ____State 2___________________________
#            T = 124.96346879157585 degC
#            P = 24.281000000024036 bar
# ...
